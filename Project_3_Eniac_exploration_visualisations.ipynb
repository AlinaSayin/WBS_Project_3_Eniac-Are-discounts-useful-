# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaSayin/WBS_Project_3_Eniac-Are-discounts-useful-/blob/main/Project_3_Eniac_exploration_visualisations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data visualisation with python

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Let's import now the Eniac clean datasets and build some plots with them:

# %%
# do not display the number with scientific notation
pd.options.display.float_format = '{:.2f}'.format

# %%
# import cleaned versions of files

# orderlines_cl.csv
url = 'https://drive.google.com/file/d/1lrSr_vVbXN7QSVSScf68DpWwvCMclK5m/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orderlines = pd.read_csv(path)

# orders_cl.csv
url = 'https://drive.google.com/file/d/1cGjJ9o3vtwjK0Sohyr3YVTccXfnTPijT/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
orders = pd.read_csv(path)

# brands_cl.csv
url = 'https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
brands = pd.read_csv(path)

# products_cl.csv
url = 'https://drive.google.com/file/d/1rHC8M-HG13FtVncImXBydgDtIHyCPH0g/view?usp=sharing' 
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
products = pd.read_csv(path)

# %% [markdown]
# Transform to date format the columns from orders and orderlines:

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293743 entries, 0 to 293742
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293743 non-null  int64
#  1   id_order          293743 non-null  int64
#  2   product_id        293743 non-null  int64
#  3   product_quantity  293743 non-null  int64
#  4   sku               293743 non-null  object
#  5   unit_price        293743 non-null  float64
#  6   date              293743 non-null  object
#  7   total_price       293743 non-null  float64
#  8   check_orders      293743 non-null  bool
# dtypes: bool(1), float64(2), int64(4), object(2)
# memory usage: 18.2+ MB

# %%
orders['created_date'] = pd.to_datetime(orders['created_date'])
orderlines['date'] = pd.to_datetime(orderlines['date'])

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293743 entries, 0 to 293742
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293743 non-null  int64
#  1   id_order          293743 non-null  int64
#  2   product_id        293743 non-null  int64
#  3   product_quantity  293743 non-null  int64
#  4   sku               293743 non-null  object
#  5   unit_price        293743 non-null  float64
#  6   date              293743 non-null  datetime64[ns]
#  7   total_price       293743 non-null  float64
#  8   check_orders      293743 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(4), object(1)
# memory usage: 18.2+ MB

# %%
products['price'].mean()
# Out:
# 667.3462680144115

# %% [markdown]
# ## Company revenue

# %% [markdown]
# First I will need to filter only the orders that have a completed state:

# %%
orders_compl = orders.query('state == "Completed"')

# %% [markdown]
# Before we create a visualisation, we always need to prepare our dataframe:

# %%
p_df = (
orders_compl
    # create two new columns in our dataframe; year and month
    .assign(year = orders['created_date'].dt.strftime('%Y'), 
           month = orders['created_date'].dt.strftime('%b'))
    # get the total paid by each year and month
    .groupby(['year','month'])
    .agg({'total_paid':'sum'})
    # reset the index to user the column vector in our plot
    .reset_index()
)
p_df
# Out:
#     year month  total_paid
# 0   2017   Apr   486962.21
# 1   2017   Aug   722055.81
# 2   2017   Dec  1897507.75
# 3   2017   Feb   623896.30
# 4   2017   Jan  1191437.34
# 5   2017   Jul  1127172.80
# 6   2017   Jun   690049.94
# 7   2017   Mar   115937.31
# 8   2017   May   646147.86
# 9   2017   Nov  2949487.12
# 10  2017   Oct  1087801.23
# 11  2017   Sep   861186.73
# 12  2018   Feb  1069705.72
# 13  2018   Jan  1960839.27
# 14  2018   Mar   476872.50

# %%
# Create a list with the months sorted from January to December
# It is going to help us sort our columns appropriately
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# define the size of the plot
# using matplotlib (plt), which operates together with seaborn
plt.subplots(figsize=(12, 8))

p = sns.barplot(
    data=p_df, # dataframe we will use to look for the columns information
    x='month', # x values on our chart
    y='total_paid', # y values on our chart
    hue='year', # group color in our chart
    order=months # order x columns
)

# %% [markdown]
# Once we have the main plot, in this case `p`, we can add additional elements to it. For example, a horizontal line (using `axhline`).
#
# We can also use `plt` to define other elements of the plot such as the title, the labels of the axis or the style:

# %%
# our main plot
plt.subplots(figsize=(12, 8))

p = sns.barplot(
    data=p_df, # dataframe we will use to look for the columns information
    x='month', # x values on our chart
    y='total_paid', # y values on our chart
    hue='year', # group color in our chart
    order=months # order x columns
)

# add a horizontal reference line into the chart to know where the mean value will be
p.axhline(
    p_df['total_paid'].mean(), # value where you want to add your reference line
    linestyle='--', # type of line you would like to see on the plot. You can find more informaiton on its documentation
    color='gray'
)

plt.xlabel('Month') # x label name
plt.ylabel('Total paid') # y label name
plt.title('Total paid evolution through 2017 and 2018') # title
plt.ticklabel_format(style='plain', axis='y') # remove scientific notation for the y axis
plt.show() # show the plot

# %% [markdown]
# ### Revenue distribution by order id

# %% [markdown]
# I would like to know more about the different values of `total_paid` for each order by month.
#
# Let's talk more about this concept:

# %%
p_df = (
orders_compl
    # create year and month
    .assign(year = orders['created_date'].dt.strftime('%Y'), 
           month = orders['created_date'].dt.strftime('%b'))
)
p_df
# Out:
#         order_id        created_date  total_paid      state  check_orders  \
# 1         241423 2017-11-06 13:10:02      136.15  Completed          True
# 2         242832 2017-12-31 17:40:03       15.76  Completed          True
# 3         243330 2017-02-16 10:59:38       84.98  Completed          True
# 5         245275 2017-06-28 11:35:37      149.00  Completed          True
# 6         245595 2017-01-21 12:52:47      112.97  Completed          True
# ...          ...                 ...         ...        ...           ...
# 204403    527042 2018-03-14 11:47:50       18.98  Completed          True
# 204423    527070 2018-03-14 11:50:48       24.97  Completed          True
# 204426    527074 2018-03-14 11:51:42       24.97  Completed          True
# 204444    527096 2018-03-14 11:58:40       34.96  Completed          True
# 204456    527112 2018-03-14 12:03:52       14.98  Completed          True
#
#         year month
# 1       2017   Nov
# 2       2017   Dec
# 3       2017   Feb
# 5       2017   Jun
# 6       2017   Jan
# ...      ...   ...
# 204403  2018   Mar
# 204423  2018   Mar
# 204426  2018   Mar
# 204444  2018   Mar
# 204456  2018   Mar
#
# [46560 rows x 7 columns]

# %% [markdown]
# If we create a barplot directly:

# %%
plt.subplots(figsize=(12, 8))

sns.barplot(data=p_df, x='month', y='total_paid', hue='year', order=months)

plt.xlabel('Month')
plt.ylabel('Total paid')
plt.title('Total paid evolution through 2017 and 2018')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# A better way to see the distribution by month would be to use another type of chart; the boxplot.

# %%
plt.subplots(figsize=(12, 8))

sns.boxplot(data=p_df, 
            x='month', 
            y='total_paid', 
            hue='year', 
            order=months)

plt.ylim(0, 800) # define a limit to put focus on your chart
plt.xlabel('Month')
plt.ylabel('Total paid')
plt.title('Total paid evolution through 2017 and 2018')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Out:
#            total_paid
#                 count   mean     std  min   25%    50%    75%      max
# year month
# 2017 Apr      1632.00 298.38  614.30 4.99 49.99  89.99 262.98  9423.90
#      Aug      2350.00 307.26  599.39 7.78 51.10 109.99 317.23 10586.97
#      Dec      5506.00 344.63  585.87 6.98 49.98 119.98 362.97  6657.46
#      Feb      2273.00 274.48  520.73 3.99 42.98  94.97 254.98  4163.98
#      Jan      5111.00 233.11  522.33 0.00 37.93  72.96 174.98  7230.97
#      Jul      3438.00 327.86  602.56 7.48 44.98 110.97 365.99  7216.77
#      Jun      1603.00 430.47  752.93 8.89 54.98 137.98 419.98  6698.00
#      Mar       202.00 573.95 1208.63 2.82 39.99 106.98 326.74  9987.76
#      May      1892.00 341.52  594.72 8.98 56.25 115.00 318.96  5335.00
#      Nov      7187.00 410.39  683.62 6.53 71.48 161.23 418.98 13387.78
#      Oct      3135.00 346.99  610.90 6.98 49.98 122.24 344.07  6227.77
#      Sep      2180.00 395.04  682.26 6.98 52.20 131.78 380.38  7376.58
# 2018 Feb      3334.00 320.85  587.50 6.98 49.98 113.97 292.98  6034.97
#      Jan      5202.00 376.94  665.62 6.48 53.99 112.97 362.99  7268.58
#      Mar      1515.00 314.77  633.07 6.98 44.98  96.98 258.04  6656.98

# %% [markdown]
# As you can see, most of our transactions have monthly median values around 100, but maximum values go up to 10,000 and the standard deviation is huge. So we have very different types of customers.
#
# A possible hypothesis is that we have a large group of low-paying customers who are end-users and a small group of 'whale' customers who are companies.

# %% [markdown]
# ### Revenue: zoom in January

# %% [markdown]
# We can zoom into the distribution of one month by filtering one month in our dataset:

# %%
p_df_jan = p_df.query('month == "Jan"')

# %%
plt.subplots(figsize=(18, 10))

sns.histplot(data=p_df_jan, x='total_paid', hue='year', 
             alpha=.4, # add transparency to you chart
             kde=True, # add a density line in the histogram
             bins=200 # define the number of bins the variable total paid will be grouped
            )
sns.set_style("white")

plt.xlim(0, 1800)
plt.title('Comparing the distributions of total paid between Jan 2017/18')
plt.xlabel('Total paid')
sns.despine() # remove the top and right margin, to make your plot prettier 
sns.set_style("white")

# %% [markdown]
# Looking at these distributions, we can see that in 2017 there were more orders with a smaller `total_paid`, while in 2018 we observe several spikes between 1000 and 1500, indicating that there were more expensive orders.
#
# Let's check this hypothesis:

# %%
p_df_jan.groupby('year').agg({'total_paid':['mean','median','std']})
# Out:
#      total_paid
#            mean median    std
# year
# 2017     233.11  72.96 522.33
# 2018     376.94 112.97 665.62

# %% [markdown]
# My theory is confirmed when we aggregate the data. The standard deviation for 2018 also shows us that there is a higher dispersion compared to 2017, caused mainly but these orders around 1250 euros.
#
# Let's see if we can zoom in into the products information for January.

# %%
# we already have the completed orders for January of both years in our p_df_jan, 
# let's locate them on the orderlines dataset:

p_sku_jan = (
orderlines
    .loc[orderlines['id_order'].isin(p_df_jan['order_id'])] # filter all the orders id in orderlines for month of january (2017 and 2018)
    .assign(year = orderlines['date'].dt.strftime('%Y')) # create year column
    .groupby(['year','sku']) # group by year and sku
    .agg({'unit_price':'sum'}) # aggregate using the sum of the "unit price"
    .reset_index() # reset index so "year" and "sku" become columns
    .sort_values('unit_price', ascending=False) # order by "unit price" to get top products
    .groupby('year') # group by year because we want the top products for each year
    .head(10) # get the first 10 products for each year
)
p_sku_jan
# Out:
#       year      sku  unit_price
# 2370  2018  APP2490    57099.45
# 2371  2018  APP2491    50301.34
# 2255  2018  APP2074    50154.26
# 2369  2018  APP2489    45337.70
# 2373  2018  APP2492    38541.00
# 2425  2018  APP2637    35826.00
# 3456  2018  PAC2119    25979.77
# 2256  2018  APP2075    23829.55
# 1323  2017  PAC1240    21966.00
# 3463  2018  PAC2136    20970.90
# 855   2017  LGE0044    20341.65
# 3454  2018  PAC2115    17588.95
# 231   2017  APP1810    17399.89
# 262   2017  APP1940    12564.93
# 1299  2017  PAC1035    12043.96
# 236   2017  APP1818    11939.96
# 250   2017  APP1876    11644.97
# 1854  2017  WAC0090    10183.36
# 858   2017  LGE0047     8819.93
# 1296  2017  PAC0963     8366.97

# %% [markdown]
# We can now merge these top 10 products from each year (coming from orderlines) with the products dataset, so that we can can obtain the names of those products:

# %%
p_sku_jan = p_sku_jan.merge(products, how='left')
p_sku_jan
# Out:
#     year      sku  unit_price  \
# 0   2018  APP2490    57099.45
# 1   2018  APP2491    50301.34
# 2   2018  APP2074    50154.26
# 3   2018  APP2489    45337.70
# 4   2018  APP2492    38541.00
# 5   2018  APP2637    35826.00
# 6   2018  PAC2119    25979.77
# 7   2018  APP2075    23829.55
# 8   2017  PAC1240    21966.00
# 9   2018  PAC2136    20970.90
# 10  2017  LGE0044    20341.65
# 11  2018  PAC2115    17588.95
# 12  2017  APP1810    17399.89
# 13  2017  APP1940    12564.93
# 14  2017  PAC1035    12043.96
# 15  2017  APP1818    11939.96
# 16  2017  APP1876    11644.97
# 17  2017  WAC0090    10183.36
# 18  2017  LGE0047     8819.93
# 19  2017  PAC0963     8366.97
#
#                                                  name  \
# 0                          Apple iPhone 64GB X Silver
# 1                     Apple iPhone X 256GB Space Gray
# 2   Apple MacBook Pro 15 "Core i7 Touch Bar 28GHz ...
# 3                      Apple iPhone 64GB Space Gray X
# 4                         Apple iPhone X 256GB Silver
# 5   Apple iMac Pro 27 "8-core Intel Xeon W 32GHz |...
# 6   Apple iMac 27 "Core i7 Retina 5K 42GHz | 32GB ...
# 7   Apple MacBook Pro 15 "Core i7 Touch Bar 29Ghz ...
# 8   Apple MacBook Pro 133 "i5 25GHz | RAM 16GB | 5...
# 9   Apple iMac 27 "Core i5 Retina 5K 34GHz | 16GB ...
# 10       LG 27UD88-W Monitor 27 "UHD 4K USB 3.0 USB-C
# 11  Apple iMac 27 "Core i7 Retina 5K 42GHz | 64GB ...
# 12  Apple MacBook Pro 13 "Core i5 2GHz | 8GB RAM |...
# 13  Apple MacBook Pro Retina 13 "i5 27 Ghz | RAM 1...
# 14  Apple iMac 27 "Core i7 Retina 5K 4GHz | 32GB |...
# 15  Apple MacBook Pro 15 "Core i7 Touch Bar 27GHz ...
# 16  Apple MacBook Pro 15 "Core i7 Touch Bar 29GHz ...
# 17           Wacom Cintiq 13HD Graphic Tablet 13 "LED
# 18       LG 38UC99-W Monitor 38 "UHD 4K USB 3.0 USB-C
# 19  Apple iMac 27 "Core i7 Retina 5K 4GHz | 32GB |...
#
#                                                  desc   price       type  \
# 0                 New Apple iPhone 64GB Free Silver X     NaN  113271716
# 1            New Apple iPhone X 256GB Free Space Gray     NaN  113271716
# 2   New MacBook Pro 15-inch Touch Bar to 28GHz Cor... 2805.59   1,02E+12
# 3                              New Free iPhone 64GB X 1159.00  113271716
# 4                New Apple iPhone X 256GB Silver Free     NaN  113271716
# 5   Pro iMac 27 inch screen Retina 5K and Intel Xe... 5499.00  118692158
# 6   IMac desktop computer 27 inch Retina 5K RAM 32... 3799.00   5,74E+15
# 7   New MacBook Pro 15-inch Core i7 Touch Bar 29Gh... 3305.59   1,02E+12
# 8   Apple MacBook Pro 133 inches (MD101Y / A) with... 1899.00       1282
# 9   IMac desktop computer 27 inch 5K Retina 16GB (... 2339.00   5,74E+15
# 10  99% Professional Monitor sRGB color calibrator...  599.00       1296
# 11  IMac desktop computer 27 inch 5K Retina 64GB R... 4639.00   5,74E+15
# 12  MacBook Pro 13 inch i5 2GHz with 8GB RAM and 2... 1699.00       2158
# 13  MacBook Pro 13-inch Retina display 27 Ghz i5 |... 1924.00       1282
# 14  IMac desktop computer 27 inch 5K Retina 4GHz i... 3649.00   5,74E+15
# 15  New MacBook Pro 15-inch Touch Bar to 27GHz Cor... 3199.00       2158
# 16  New MacBook Pro 15-inch Core i7 Touch Bar 29Gh... 4039.00       2158
# 17  Graphics Tablet 13-inch LED HD display with 20...  899.99       1405
# 18  Monitor curved 38 inch IPS 4K ultra high defin... 1299.00       1296
# 19  IMac desktop computer 27 inch 5K Retina 4GHz i... 3409.00   5,74E+15
#
#     max_price_orderlines
# 0                1159.00
# 1                1329.00
# 2                    NaN
# 3                    NaN
# 4                1329.00
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN

# %% [markdown]
# Time to visualize the products:

# %%
# data for 2017
year = "2017"
data_2017 = p_sku_jan.loc[p_sku_jan['year'] == year]

# plot for 2017
sns.barplot(data= data_2017, 
            x='unit_price', 
            y='name',
            color='dodgerblue')

plt.title('Top 10 products for Jan ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %%
# data for 2018
year = "2018"
data_2018 = p_sku_jan.loc[p_sku_jan['year'] == year]

# plot for 2018
sns.barplot(data= data_2018, 
            x='unit_price', 
            y='name',
            color='dodgerblue')

plt.title('Top 10 products for Jan ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %% [markdown]
# Whenever you repeat a task in python with minimal changes, there's usually a way to do it with a loop. You don't need to understand the code below, but feel free to scrutinize it:

# %%
for year in ['2017', '2018']:
    temp = p_sku_jan.loc[p_sku_jan['year'] == year]
    sns.barplot(data=temp, x='unit_price', y='name', color='dodgerblue')
    plt.title('Top 10 products for Jan ' + year)
    plt.xlabel('Total generated income')
    plt.show()

# %% [markdown]
# ### **Question 1:**
# We saw above that the top 10 products for 2018 was composed of significantly more Apple products than the same top 10 for 2017. I'd like to investigate this business trend further.
#
# Create a bar graph showing the total number of Apple products sold for each month

# %%
orderlines
# Out:
#              id  id_order  product_id  product_quantity      sku  unit_price  \
# 0       1119109    299539           0                 1  OTT0133       18.99
# 1       1119110    299540           0                 1  LGE0043      399.00
# 2       1119111    299541           0                 1  PAR0071      474.05
# 3       1119112    299542           0                 1  WDT0315       68.39
# 4       1119113    299543           0                 1  JBL0104       23.74
# ...         ...       ...         ...               ...      ...         ...
# 293738  1650199    527398           0                 1  JBL0122       42.99
# 293739  1650200    527399           0                 1  PAC0653      141.58
# 293740  1650201    527400           0                 2  APP0698        9.99
# 293741  1650202    527388           0                 1  BEZ0204       19.99
# 293742  1650203    527401           0                 1  APP0927       13.99
#
#                       date  total_price  check_orders
# 0      2017-01-01 00:07:19        18.99          True
# 1      2017-01-01 00:19:45       399.00          True
# 2      2017-01-01 00:20:57       474.05          True
# 3      2017-01-01 00:51:40        68.39          True
# 4      2017-01-01 01:06:38        23.74          True
# ...                    ...          ...           ...
# 293738 2018-03-14 13:57:25        42.99          True
# 293739 2018-03-14 13:57:34       141.58          True
# 293740 2018-03-14 13:57:41        19.98          True
# 293741 2018-03-14 13:58:01        19.99          True
# 293742 2018-03-14 13:58:36        13.99          True
#
# [293743 rows x 9 columns]

# %%
p_sku_month = (
orderlines
    .loc[(orderlines.sku == 'APP%') | (orderlines.sku == 'AP2%')]
    .assign(year = orderlines['date'].dt.strftime('%Y'), month = orderlines['date'].dt.strftime('%b'))
    .groupby(['year','month']) # group by year and sku
    .agg({'unit_price':'sum'}) # aggregate using the sum of the "unit price"
    .reset_index() # reset index so "year" and "sku" become columns
    .sort_values('unit_price', ascending=False) # order by "unit price" to get top products
    .head(20) # get the first 10 products for each year
)
p_sku_month
# Out:
#     year month  unit_price
# 0   2017   Apr        0.00
# 1   2017   Aug        0.00
# 2   2017   Dec        0.00
# 3   2017   Feb        0.00
# 4   2017   Jan        0.00
# 5   2017   Jul        0.00
# 6   2017   Jun        0.00
# 7   2017   Mar        0.00
# 8   2017   May        0.00
# 9   2017   Nov        0.00
# 10  2017   Oct        0.00
# 11  2017   Sep        0.00
# 12  2018   Feb        0.00
# 13  2018   Jan        0.00
# 14  2018   Mar        0.00

# %%
# data for 2018
year = "2018"
data_month = p_sku_month.loc[p_sku_month['year'] == year]

# plot for 2018
sns.barplot(data= data_month, 
            x = 'month',
            y ='unit_price')

plt.title('Top 10 products for each month ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %%
# data for 2017
year = "2017"
data_month = p_sku_month.loc[p_sku_month['year'] == year]

# plot for 2018
sns.barplot(data= data_month, 
            x = 'month',
            y ='unit_price')

plt.title('Top 10 products for each month ' + year)
plt.xlabel('Total generated revenue')
plt.show()

# %%
p_df

# %% [markdown]
# ### **Q 2:**
# Continuing our theme of barplots - make a bar plot showing the amount of orders placed per hour. If we can see that more orders are placed at 3pm compared to 3am, we know when is best to do maintenance work on the servers

# %%
ch_2 = (
orderlines
    .loc[orderlines['id_order'].isin(p_df['order_id'])] # filter all the orders id in orderlines  (2017 and 2018)
    .assign(hour = orderlines['date'].dt.strftime('%H')) #create new column with just hours
    .groupby('hour') # group by hour  
    .agg({'id_order':'count'}) # aggregate using the sum of the "unit price"
    .reset_index() # reset index so hour becomes a column
    .sort_values('hour', ascending=True) # order by "id_order" to get top products
    .head(20) # get the first 10 products for each year
)
ch_2
# Out:
#    hour  id_order
# 0    00      1884
# 1    01       952
# 2    02       447
# 3    03       215
# 4    04       138
# 5    05       136
# 6    06       262
# 7    07       664
# 8    08      1845
# 9    09      3428
# 10   10      4685
# 11   11      5122
# 12   12      5291
# 13   13      4491
# 14   14      3110
# 15   15      3130
# 16   16      3992
# 17   17      3770
# 18   18      3532
# 19   19      3292

# %%
sns.barplot(data= ch_2,
            x ='hour',
            y ='id_order')
plt.title('Amount of orders placed per hour')
plt.xlabel('Hours')
plt.ylabel('Counted id_orders')
plt.show()

# %% [markdown]
# ### **Q 3:**
# Some items with same SKU have different unit_price for different orders
#
# Create a boxplot of unit_price for 30 most frequently sold items
#
# Use the orderlines table

# %%
ch_3 = (
orderlines
    .loc[orderlines['id_order'].isin(p_df['order_id'])] # filter all the orders id in orderlines  (2017 and 2018)
    .assign(hour = orderlines['date'].dt.strftime('%H')) #create new column with just hours
    .groupby('hour') # group by hour  
    .agg({'id_order':'count'}) # aggregate using the sum of the "unit price"
    .reset_index() # reset index so hour becomes a column
    .sort_values('hour', ascending=True) # order by "id_order" to get top products
    .head(20) # get the first 10 products for each year
)
ch_3
# Out:
#    hour  id_order
# 0    00      1884
# 1    01       952
# 2    02       447
# 3    03       215
# 4    04       138
# 5    05       136
# 6    06       262
# 7    07       664
# 8    08      1845
# 9    09      3428
# 10   10      4685
# 11   11      5122
# 12   12      5291
# 13   13      4491
# 14   14      3110
# 15   15      3130
# 16   16      3992
# 17   17      3770
# 18   18      3532
# 19   19      3292

# %% [markdown]
# ### **Q 4:**
# Show evolution for the amount of orders in different states (i.e. completed, cancelled etc...) for each month. Each state should have it's own line in different color

# %%
orders.tail()
# Out:
#         order_id        created_date  total_paid            state  \
# 204686    527397 2018-03-14 13:56:38       42.99      Place Order
# 204687    527398 2018-03-14 13:57:25       42.99  Shopping Basket
# 204688    527399 2018-03-14 13:57:34      141.58  Shopping Basket
# 204689    527400 2018-03-14 13:57:41       19.98  Shopping Basket
# 204690    527401 2018-03-14 13:58:36       18.98      Place Order
#
#         check_orders
# 204686          True
# 204687          True
# 204688          True
# 204689          True
# 204690          True

# %%
ch_4_0 = (
orders
    # create two new columns in our dataframe; year and month
    .assign(year = orders['created_date'].dt.strftime('%Y'), 
           month = orders['created_date'].dt.strftime('%b'))
    # get the total paid by each year and month
    .groupby(['year','month','state'])
    .agg({'order_id':'count'})
    # reset the index to user the column vector in our plot
    .reset_index()
    .sort_values('month', ascending=True)
)
ch_4_0
# Out:
#     year month            state  order_id
# 0   2017   Apr        Cancelled       313
# 1   2017   Apr        Completed      1632
# 2   2017   Apr          Pending      1230
# 3   2017   Apr      Place Order      1314
# 4   2017   Apr  Shopping Basket      4741
# ..   ...   ...              ...       ...
# 59  2017   Sep  Shopping Basket      5425
# 58  2017   Sep      Place Order      1462
# 57  2017   Sep          Pending       810
# 56  2017   Sep        Completed      2180
# 55  2017   Sep        Cancelled       382
#
# [75 rows x 4 columns]

# %%
orders_pending = orders.query('state == "Pending"')
orders_shopbask = orders.query('state == "Shopping Basket"')
orders_placeorder = orders.query('state == "Place Order"')
orders_compl
# Out:
#         order_id        created_date  total_paid      state  check_orders
# 1         241423 2017-11-06 13:10:02      136.15  Completed          True
# 2         242832 2017-12-31 17:40:03       15.76  Completed          True
# 3         243330 2017-02-16 10:59:38       84.98  Completed          True
# 5         245275 2017-06-28 11:35:37      149.00  Completed          True
# 6         245595 2017-01-21 12:52:47      112.97  Completed          True
# ...          ...                 ...         ...        ...           ...
# 204403    527042 2018-03-14 11:47:50       18.98  Completed          True
# 204423    527070 2018-03-14 11:50:48       24.97  Completed          True
# 204426    527074 2018-03-14 11:51:42       24.97  Completed          True
# 204444    527096 2018-03-14 11:58:40       34.96  Completed          True
# 204456    527112 2018-03-14 12:03:52       14.98  Completed          True
#
# [46560 rows x 5 columns]

# %%
lp = sns.lineplot( x ='month', y = 'order_id', ci=None, 
             hue='state', data=ch_4_0)
plt.title('Evolution for the amount of orders in different states for each month')
plt.xlabel('Months')
plt.ylabel('Counted id_orders')
plt.show()
